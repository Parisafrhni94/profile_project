# %%
import pandas as pd
import numpy as np

df= pd.read_csv("titanic.csv")

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # A. Aggregation

# %% [markdown]
# ### 1: Groupby

# %%
et = df.groupby('embark_town')

# %%
et.first()
# Out:
#              survived  pclass     sex   age  sibsp  parch     fare embarked  \
# embark_town
# Cherbourg           1       1  female  38.0      1      0  71.2833        C
# Queenstown          0       3    male   2.0      0      0   8.4583        Q
# Southampton         0       3    male  22.0      1      0   7.2500        S
#
#              class    who  adult_male deck alive  alone
# embark_town
# Cherbourg    First  woman       False    C   yes  False
# Queenstown   Third    man        True    C    no   True
# Southampton  Third    man        True    C    no  False

# %%
survived = df.groupby('survived')

# %%
survived.first()
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# survived
# 0              3    male  22.0      1      0   7.2500        S  Third    man
# 1              1  female  38.0      1      0  71.2833        C  First  woman
#
#           adult_male deck  embark_town alive  alone
# survived
# 0               True    E  Southampton    no  False
# 1              False    C    Cherbourg   yes  False

# %%
survived.describe()
# Out:
#          pclass                                                 age  \
#           count      mean       std  min  25%  50%  75%  max  count
# survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0  424.0
# 1         342.0  1.950292  0.863321  1.0  1.0  2.0  3.0  3.0  290.0
#
#                      ... parch        fare                             \
#                mean  ...   75%  max  count       mean        std  min
# survived             ...
# 0         30.626179  ...   0.0  6.0  549.0  22.117887  31.388207  0.0
# 1         28.343690  ...   1.0  5.0  342.0  48.395408  66.596998  0.0
#
#
#               25%   50%   75%       max
# survived
# 0          7.8542  10.5  26.0  263.0000
# 1         12.4750  26.0  57.0  512.3292
#
# [2 rows x 40 columns]

# %% [markdown]
# ### 2: Aggregation Methods

# %%
mean_data = df.head().aggregate("mean")
mean_data
# Out:
# /var/folders/68/l23cjsw133d5gkhpn60nw9640000gn/T/ipykernel_1708/2635795032.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_data = df.head().aggregate("mean")
# survived       0.60000
# pclass         2.20000
# age           31.20000
# sibsp          0.60000
# parch          0.00000
# fare          29.52166
# adult_male     0.40000
# alone          0.40000
# dtype: float64

# %%
sum_data = df.head().aggregate("sum")
sum_data
# Out:
# /var/folders/68/l23cjsw133d5gkhpn60nw9640000gn/T/ipykernel_1708/251141962.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sum_data = df.head().aggregate("sum")
# survived                                                       3
# pclass                                                        11
# sex                                   malefemalefemalefemalemale
# age                                                        156.0
# sibsp                                                          3
# parch                                                          0
# fare                                                    147.6083
# embarked                                                   SCSSS
# class                                  ThirdFirstThirdFirstThird
# ...

# %% [markdown]
# Note: Cannot sum string values, instead they are concatenated

# %%
test_dictionary={"survived": ["sum", "count"], 
                 "age": ["std", "min"], 
                 "sibsp": ["count","sum"]
                }

dictionary_agg=df.agg(test_dictionary)

# %%
pclass = df.groupby('pclass')
pclass.first()
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 2              1  female  14.0      1      0  30.0708        C  Second  child
# 3              0    male  22.0      1      0   7.2500        S   Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# 1            False    C    Cherbourg   yes  False
# 2            False    D    Cherbourg   yes  False
# 3             True    G  Southampton    no  False

# %%
agg_func_list = ['sum', 'mean', 'median', 'min', 'max', 'std', 'var', 'first', 'last', 'count']
pclass.agg(agg_func_list)
# Out:
# /var/folders/68/l23cjsw133d5gkhpn60nw9640000gn/T/ipykernel_1708/2951954653.py:2: FutureWarning: ['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   pclass.agg(agg_func_list)
#        survived                                                                \
#             sum      mean median min max       std       var first last count
# pclass
# 1           136  0.629630    1.0   0   1  0.484026  0.234281     1    1   216
# 2            87  0.472826    0.0   0   1  0.500623  0.250624     1    0   184
# 3           119  0.242363    0.0   0   1  0.428949  0.183998     0    0   491
#
#         ... alone                                                           \
#         ...   sum      mean median    min   max       std       var  first
# pclass  ...
# ...

# %%
agg_func_dict = {
    'age':
    ['sum', 'mean', 'median', 'min', 'max', 'std', 'var', 'first', 'last', 'count']
}

pclass.agg(agg_func_dict)
# Out:
#             age                                                             \
#             sum       mean median   min   max        std         var first
# pclass
# 1       7111.42  38.233441   37.0  0.92  80.0  14.802856  219.124543  38.0
# 2       5168.83  29.877630   29.0  0.67  70.0  14.001077  196.030152  14.0
# 3       8924.92  25.140620   24.0  0.42  74.0  12.495398  156.134976  22.0
#
#
#         last count
# pclass
# 1       26.0   186
# 2       27.0   173
# 3       32.0   355

# %%
agg_func_dict = {
    'survived':
    ['sum', 'mean', 'median', 'min', 'max', 'std', 'var', 'first', 'last', 'count']
}
pclass.agg(agg_func_dict)
# Out:
#        survived
#             sum      mean median min max       std       var first last count
# pclass
# 1           136  0.629630    1.0   0   1  0.484026  0.234281     1    1   216
# 2            87  0.472826    0.0   0   1  0.500623  0.250624     1    0   184
# 3           119  0.242363    0.0   0   1  0.428949  0.183998     0    0   491

# %% [markdown]
# # B. Recoding and Creating New Values and Variables

# %% [markdown]
# #### Creating new column

# %%
df["fare_2021"] = (df["fare"] * 117.17)  
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone    fare_2021
# 0    man        True  NaN  Southampton    no  False   849.482500
# 1  woman       False    C    Cherbourg   yes  False  8352.264261
# 2  woman       False  NaN  Southampton   yes   True   928.572250
# 3  woman       False    C  Southampton   yes  False  6221.727000
# 4    man        True  NaN  Southampton    no   True   943.218500

# %% [markdown]
# #### Replacing values

# %%
df["alive"] = df["alive"].replace({"yes":True, "no":False})
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town  alive  alone    fare_2021
# 0    man        True  NaN  Southampton  False  False   849.482500
# 1  woman       False    C    Cherbourg   True  False  8352.264261
# 2  woman       False  NaN  Southampton   True   True   928.572250
# 3  woman       False    C  Southampton   True  False  6221.727000
# 4    man        True  NaN  Southampton  False   True   943.218500

# %% [markdown]
# Function that will set the alive values as bools

# %%
def set_alive_to_number(series):
    if series == "yes":
        return True
    else:
        return False
    
df["alive"] = df["alive"].apply(set_alive_to_number) 
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# #### Using a function to create a new column

# %%
age_check = df["age"].agg("max")
age_check

def age_groups(series):
    if series <20:
        return "0-19 years"
    elif 20 <= series < 30:
        return "20-29 years"
    elif 30 <= series < 40:
        return "30-39 years"
    elif 40 <= series < 50:
        return "40-49 years"
    elif 50 <= series < 60:
        return "50-59 years"
    elif 60 <= series < 70:
        return "60-69 years"
    elif 70 <= series < 80:
        return "70-79 years"
    elif 80 <= series < 90:
        return "80-89 years"
    else:
        return "no data"
    
df["age_group"] = df["age"].apply(age_groups) 
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town  alive  alone    fare_2021    age_group
# 0    man        True  NaN  Southampton  False  False   849.482500  20-29 years
# 1  woman       False    C    Cherbourg  False  False  8352.264261  30-39 years
# 2  woman       False  NaN  Southampton  False   True   928.572250  20-29 years
# 3  woman       False    C  Southampton  False  False  6221.727000  30-39 years
# 4    man        True  NaN  Southampton  False   True   943.218500  30-39 years

# %% [markdown]
# # C. Reshaping Tables

# %% [markdown]
# #### Sort_values

# %%
sort_data = df.sort_values(by=["who","age"], ascending = False)
sort_data
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 275         1       1  female  63.00      1      0  77.9583        S   First
# 483         1       3  female  63.00      0      0   9.5875        S   Third
# 829         1       1  female  62.00      0      0  80.0000      NaN   First
# 366         1       1  female  60.00      1      0  75.2500        C   First
# 11          1       1  female  58.00      0      0  26.5500        S   First
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 831         1       2    male   0.83      1      1  18.7500        S  Second
# 469         1       3  female   0.75      2      1  19.2583        C   Third
# 644         1       3  female   0.75      2      1  19.2583        C   Third
# 755         1       2    male   0.67      1      1  14.5000        S  Second
# 803         1       3    male   0.42      0      1   8.5167        C   Third
#
# ...

# %% [markdown]
# #### pivot_table

# %%
data_pt = df.pivot_table("fare", ["who", "age_group"], "survived", aggfunc = np.sum)

# %%
data_pt
# Out:
# survived                   0          1
# who   age_group
# child 0-19 years   1109.5459  1611.6751
# man   0-19 years    978.4249   145.5333
#       20-29 years  2435.2329   646.9542
#       30-39 years  1506.2789  1720.9459
#       40-49 years  1110.6374   466.6793
#       50-59 years   853.3042   226.2000
#       60-69 years   586.4875    89.7000
#       70-79 years   181.1834        NaN
#       80-89 years        NaN    30.0000
#       no data      1997.7913   376.7124
# woman 0-19 years    126.1375  1243.0209
#       20-29 years   404.7500  2514.4291
#       30-39 years   164.9042  3350.8791
#       40-49 years   241.2542  1563.6335
#       50-59 years    39.2125  1182.0833
#       60-69 years        NaN   242.7958
#       no data       407.5751  1139.9875

# %% [markdown]
# #### Wide to Long

# %%
wide_long = df.pivot(columns="who", values="age_group")

# %%
wide_long
# Out:
# who child          man        woman
# 0     NaN  20-29 years          NaN
# 1     NaN          NaN  30-39 years
# 2     NaN          NaN  20-29 years
# 3     NaN          NaN  30-39 years
# 4     NaN  30-39 years          NaN
# ..    ...          ...          ...
# 886   NaN  20-29 years          NaN
# 887   NaN          NaN   0-19 years
# 888   NaN          NaN      no data
# 889   NaN  20-29 years          NaN
# 890   NaN  30-39 years          NaN
#
# [891 rows x 3 columns]

# %%
data_m=pd.melt(df)
data_m.shape
# Out:
# (15147, 2)

# %%
data_melt = pd.melt(data, id_vars=["embarked"], value_vars=["fare", "deck"])
data_melt.shape
# Out:
# (1782, 3)
