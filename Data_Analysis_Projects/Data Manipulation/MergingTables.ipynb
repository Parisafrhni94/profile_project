# %%
import pandas as pd

# %% [markdown]
# # *Data Manipulation:*  Appending, Concatinating, Merging, and Joining Tables

# %%
flowers = pd.DataFrame({
    "Name" : ["Iris", "Peony", "Daisy", "Petunia", "Impatiens", "Creeping Myrtle"], 
    "Plant_Type" : ["Perennial", "Perennial","Annual", "Annual", "Annual", "Perennial"],
    "Sun_Shade": ["Full Sun", "Full Sun", "Partial Sun", "Partial Sun", "Partial Shade", "Full Shade" ]
    
})

garden_supply = pd.DataFrame({
    "Flower" : ["Daylily","Iris", "Peony","Petunia", "Petunia", "Impatiens", "Coneflower"],
    "Sold_As" : ["Container", "Bulb Pack", "Root Pack","Container Pack", "Mixed Container", "Container Pack", "Container"],
    "Amt_Package" : [1, 25, 5, 4, 1, 4, 1]
})

shrubs = pd.DataFrame({
    "Name" : ["Boxwood", "Hydrangea", "Dipladenia", "Gardenia"], 
    "Plant_Type" : ["Evergreen", "Flowering", "Flowering", "Flowering"],
    "Sun_Shade": ["Partial Sund", "Partial Sun", "Partial Shade", "Full Sun" ]
})

# %% [markdown]
# # Part 1: Append

# %%
append_plants = flowers.append(shrubs)
# Out:
# /var/folders/68/l23cjsw133d5gkhpn60nw9640000gn/T/ipykernel_4548/1970895660.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   append_plants = flowers.append(shrubs)

# %%
append_plants = flowers.append(shrubs, ignore_index=True)
# Out:
# /var/folders/68/l23cjsw133d5gkhpn60nw9640000gn/T/ipykernel_4548/554633031.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   append_plants = flowers.append(shrubs, ignore_index=True)

# %% [markdown]
# # Part 2: Concatenation

# %%
# Concatenate flowers and shrubs horizontally:

flowers_shrubs = pd.concat([flowers, shrubs], axis=1)

# %% [markdown]
# # Part 3:  Merge

# %%
# This code is not working
# flowers.merge(garden_supply)

# %% [markdown]
# ### Option 1:  Rename a column in the flowers table.
#
# Create a variable to hold your updated table.
# apply the following syntax to update your column names: **table_name.rename(columns={"original_name": "new_name"})**

# %%
rename_flowers_col = flowers.rename(columns={"Name": "Flower"})

# %% [markdown]
# #### Option 1 Testing:
# Merge garden_supply with you updated table in a new variable.
# Run your newly merged table and examine it.

# %%
merge_rename = rename_flowers_col.merge(garden_supply)
merge_rename.head(5)
# Out:
#       Flower Plant_Type      Sun_Shade          Sold_As  Amt_Package
# 0       Iris  Perennial       Full Sun        Bulb Pack           25
# 1      Peony  Perennial       Full Sun        Root Pack            5
# 2    Petunia     Annual    Partial Sun   Container Pack            4
# 3    Petunia     Annual    Partial Sun  Mixed Container            1
# 4  Impatiens     Annual  Partial Shade   Container Pack            4

# %% [markdown]
# ### Option 2: Using the merge method's parameters "left_on" & "right_on"
#
# Option 2 can be used when if you would rather not rename any columns.
#
# Syntax:  **left_table.merge(right_table, left_on="column_name", right_on="column_name")**

# %%
merge_only = flowers.merge(garden_supply, left_on="Name", right_on="Flower")
merge_only.head(5)
# Out:
#         Name Plant_Type      Sun_Shade     Flower          Sold_As  \
# 0       Iris  Perennial       Full Sun       Iris        Bulb Pack
# 1      Peony  Perennial       Full Sun      Peony        Root Pack
# 2    Petunia     Annual    Partial Sun    Petunia   Container Pack
# 3    Petunia     Annual    Partial Sun    Petunia  Mixed Container
# 4  Impatiens     Annual  Partial Shade  Impatiens   Container Pack
#
#    Amt_Package
# 0           25
# 1            5
# 2            4
# 3            1
# 4            4

# %% [markdown]
# ### Sytnax Exploring:
# Using the syntax in Option 2, perform the same merge, but this time *garden_supply* on the left and *flowers* on the right.

# %%
merge_only1 = garden_supply.merge(flowers, left_on="Flower", right_on="Name")
merge_only1.head(5)
# Out:
#       Flower          Sold_As  Amt_Package       Name Plant_Type  \
# 0       Iris        Bulb Pack           25       Iris  Perennial
# 1      Peony        Root Pack            5      Peony  Perennial
# 2    Petunia   Container Pack            4    Petunia     Annual
# 3    Petunia  Mixed Container            1    Petunia     Annual
# 4  Impatiens   Container Pack            4  Impatiens     Annual
#
#        Sun_Shade
# 0       Full Sun
# 1       Full Sun
# 2    Partial Sun
# 3    Partial Sun
# 4  Partial Shade

# %% [markdown]
# # Part 4:  Types of Merges

# %% [markdown]
# ## 4a: Inner Merge

# %%
inner = pd.merge(flowers, garden_supply, how="inner", left_on="Name", right_on="Flower", indicator=True)
inner.head(5)
# Out:
#         Name Plant_Type      Sun_Shade     Flower          Sold_As  \
# 0       Iris  Perennial       Full Sun       Iris        Bulb Pack
# 1      Peony  Perennial       Full Sun      Peony        Root Pack
# 2    Petunia     Annual    Partial Sun    Petunia   Container Pack
# 3    Petunia     Annual    Partial Sun    Petunia  Mixed Container
# 4  Impatiens     Annual  Partial Shade  Impatiens   Container Pack
#
#    Amt_Package _merge
# 0           25   both
# 1            5   both
# 2            4   both
# 3            1   both
# 4            4   both

# %% [markdown]
# contains shared between left and right table, where name = flower

# %% [markdown]
# ## 4b: Left Merge

# %%
left = pd.merge(flowers, garden_supply, how="left", left_on="Name", right_on="Flower", indicator=True)
left.head(5)
# Out:
#       Name Plant_Type    Sun_Shade   Flower          Sold_As  Amt_Package  \
# 0     Iris  Perennial     Full Sun     Iris        Bulb Pack         25.0
# 1    Peony  Perennial     Full Sun    Peony        Root Pack          5.0
# 2    Daisy     Annual  Partial Sun      NaN              NaN          NaN
# 3  Petunia     Annual  Partial Sun  Petunia   Container Pack          4.0
# 4  Petunia     Annual  Partial Sun  Petunia  Mixed Container          1.0
#
#       _merge
# 0       both
# 1       both
# 2  left_only
# 3       both
# 4       both

# %% [markdown]
# ## 4c: Right Merge

# %%
right = pd.merge(flowers, garden_supply, how="right", left_on="Name", right_on="Flower", indicator=True)
right.head(5)
# Out:
#       Name Plant_Type    Sun_Shade   Flower          Sold_As  Amt_Package  \
# 0      NaN        NaN          NaN  Daylily        Container            1
# 1     Iris  Perennial     Full Sun     Iris        Bulb Pack           25
# 2    Peony  Perennial     Full Sun    Peony        Root Pack            5
# 3  Petunia     Annual  Partial Sun  Petunia   Container Pack            4
# 4  Petunia     Annual  Partial Sun  Petunia  Mixed Container            1
#
#        _merge
# 0  right_only
# 1        both
# 2        both
# 3        both
# 4        both

# %% [markdown]
# All values from right table and any shared values in the left table are contained in the table.
# Any values that are only in the left table are represented by "NaN" and are not in this table.

# %% [markdown]
# ## Outer Merge

# %%
outer = pd.merge(flowers, garden_supply, how="outer", left_on="Name", right_on="Flower", indicator=True)
outer.head(5)
# Out:
#       Name Plant_Type    Sun_Shade   Flower          Sold_As  Amt_Package  \
# 0     Iris  Perennial     Full Sun     Iris        Bulb Pack         25.0
# 1    Peony  Perennial     Full Sun    Peony        Root Pack          5.0
# 2    Daisy     Annual  Partial Sun      NaN              NaN          NaN
# 3  Petunia     Annual  Partial Sun  Petunia   Container Pack          4.0
# 4  Petunia     Annual  Partial Sun  Petunia  Mixed Container          1.0
#
#       _merge
# 0       both
# 1       both
# 2  left_only
# 3       both
# 4       both

# %% [markdown]
# ## Anti_Merge
#
# An **Anti Merge** is a merge based on what is leftout.  This is not an actual table, but you can create one with a little code and logic.  Read through the code below to see one way to create an anti-table.

# %%
left_join = flowers.merge(garden_supply, how="left", left_on="Name", right_on="Flower", indicator=True) 
left_only = left_join.loc[left_join["_merge"] =="left_only", "Name"]
left_only_flowers=flowers[flowers["Name"].isin(left_only)]
left_only_flowers.head(5)
# Out:
#               Name Plant_Type    Sun_Shade
# 2            Daisy     Annual  Partial Sun
# 5  Creeping Myrtle  Perennial   Full Shade

# %% [markdown]
# 1) Started by merging our table together (left_join)
# 2) Create a variable to hold our "left_only" flowers
# 3) Created table contianing items in the left_only variable

# %% [markdown]
# # Part 5: Join

# %%
join = flowers.join(garden_supply)
join.head(5)
# Out:
#         Name Plant_Type      Sun_Shade   Flower          Sold_As  Amt_Package
# 0       Iris  Perennial       Full Sun  Daylily        Container            1
# 1      Peony  Perennial       Full Sun     Iris        Bulb Pack           25
# 2      Daisy     Annual    Partial Sun    Peony        Root Pack            5
# 3    Petunia     Annual    Partial Sun  Petunia   Container Pack            4
# 4  Impatiens     Annual  Partial Shade  Petunia  Mixed Container            1

# %%
join_inner = garden_supply.join(flowers, how="inner")
join_inner.head(5)
# Out:
#     Flower          Sold_As  Amt_Package       Name Plant_Type      Sun_Shade
# 0  Daylily        Container            1       Iris  Perennial       Full Sun
# 1     Iris        Bulb Pack           25      Peony  Perennial       Full Sun
# 2    Peony        Root Pack            5      Daisy     Annual    Partial Sun
# 3  Petunia   Container Pack            4    Petunia     Annual    Partial Sun
# 4  Petunia  Mixed Container            1  Impatiens     Annual  Partial Shade

# %%
join_outer = garden_supply.join(flowers, how="outer")
join_outer.head(5)
# Out:
#     Flower          Sold_As  Amt_Package       Name Plant_Type      Sun_Shade
# 0  Daylily        Container            1       Iris  Perennial       Full Sun
# 1     Iris        Bulb Pack           25      Peony  Perennial       Full Sun
# 2    Peony        Root Pack            5      Daisy     Annual    Partial Sun
# 3  Petunia   Container Pack            4    Petunia     Annual    Partial Sun
# 4  Petunia  Mixed Container            1  Impatiens     Annual  Partial Shade

# %% [markdown]
# Starts with shared elements, then 6 is only found in the garden supply table
